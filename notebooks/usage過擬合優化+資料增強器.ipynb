# %%
# 連接至 google drive
from google.colab import drive
drive.mount('/content/drive')
# 新增資料夾
# %cd /root
# !mkdir datasets
# 下載並解壓縮人臉表情資料庫
# %cd datasets
# !unzip "/content/drive/MyDrive/Colab Notebooks/fer2013csv.zip"
# Out:
# Mounted at /content/drive
# /root
# /root/datasets
# Archive:  /content/drive/MyDrive/Colab Notebooks/fer2013csv.zip
#   inflating: fer2013.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 載入資料，並存放於DataFrame資料型態中
filname = '/root/datasets/fer2013.csv' # 如下圖所示
label_map = ['Anger', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
names=['emotion','pixels','usage']
df=pd.read_csv(filname,names=names, na_filter=False)
df.head()
# Out:
#    emotion                                             pixels     usage
# 0  emotion                                             pixels     Usage
# 1        0  70 80 82 72 58 58 60 63 54 58 60 48 89 115 121...  Training
# 2        0  151 150 147 155 148 133 111 140 170 174 182 15...  Training
# 3        2  231 212 156 164 174 138 161 173 182 200 106 38...  Training
# 4        4  24 32 36 30 32 23 19 20 30 41 21 22 32 34 21 1...  Training

# %%
import pandas as pd
import numpy as np

# 1. 讀取 CSV，並保留欄位名稱
filname = '/root/datasets/fer2013.csv'
df = pd.read_csv(filname)

# 2. 將三個子集依據 usage 欄位分開
train_df = df[df['Usage'] == 'Training']
val_df   = df[df['Usage'] == 'PublicTest']
test_df  = df[df['Usage'] == 'PrivateTest']

# 3. 建立轉換像素字串為 48x48 陣列的函式
def preprocess(df):
    X = np.array([np.fromstring(pix, sep=' ') for pix in df['pixels']]) / 255.0
    X = X.reshape(-1, 48, 48, 1)  # 灰階影像 reshape 成 CNN 格式
    Y = df['emotion'].astype(int).values
    return X, Y

# 4. 對三個子集分別處理
X_train, y_train = preprocess(train_df)
X_val, y_val     = preprocess(val_df)
X_test, y_test   = preprocess(test_df)

# 5. One-hot 編碼（共 7 類情緒）
num_class = len(np.unique(y_train))  # 應為 7

y_train = (np.arange(num_class) == y_train[:, None]).astype(np.float32)
y_val   = (np.arange(num_class) == y_val[:, None]).astype(np.float32)
y_test  = (np.arange(num_class) == y_test[:, None]).astype(np.float32)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=30,       # 隨機旋轉角度
    width_shift_range=0.2,   # 水平平移
    height_shift_range=0.2,  # 垂直平移
    zoom_range=0.2,          # 隨機縮放
    shear_range=0.15,        # 隨機錯切
    horizontal_flip=True     # 隨機左右翻轉
)
train_generator = datagen.flow(
    X_train, y_train,
    batch_size=64
)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# 建立模組架構
model = Sequential()#初始化模型與輸入維度(初始化一個 序列模型（Sequential），適合用於逐層堆疊的神經網路架構。)
input_shape = (48,48,1)#設定輸入圖片的形狀為 48x48 的灰階圖 其中 1 表示只有一個顏色通道（灰階）
model.add(Conv2D(64, (5, 5), input_shape=input_shape,activation='relu', padding='same')) # 卷積層(使用 64 個 5x5 的濾波器（filter/kernels）) # 啟用函數為 ReLU（正向線性單元）
model.add(Conv2D(64, (5, 5), activation='relu', padding='same')) ## 卷積層
model.add(BatchNormalization())   # 批次正規化：加速訓練並提高穩定性，將每層輸出的分佈標準化
model.add(MaxPooling2D(pool_size=(2, 2))) # 最大池化層
model.add(Conv2D(128, (5, 5),activation='relu',padding='same')) # 卷積層
model.add(Conv2D(128, (5, 5),activation='relu',padding='same')) # 卷積層
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2))) # 最大池化層
model.add(Conv2D(256, (3, 3),activation='relu',padding='same')) # 卷積層
model.add(Conv2D(256, (3, 3),activation='relu',padding='same')) # 卷積層
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2))) # 最大池化層
model.add(Flatten())
model.add(Dense(128)) # 全連接層
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))#在訓練過程中隨機關閉 20% 的神經元
model.add(Dense(7)) # 全連接層
model.add(Activation('softmax'))
# 最佳化參數與損失函式設定 -> 這裡取用 'categorical_crossentropy' 作為損失函示、採用 Adam 的最佳化方法
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
model.summary()

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    verbose=1
)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 48, 48, 64)     │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 48, 48, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 24, 24, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 24, 24, 128)    │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           903 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 7)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,787,015 (10.63 MB)
#  Trainable params: 2,785,863 (10.63 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
import time
start = time.time()
history = model.fit(
    train_generator,
    epochs=20,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr]
)
end = time.time()
print(f"總訓練時間: {(end - start)/60:.2f} 分鐘")
# Out:
# Epoch 1/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - accuracy: 0.2241 - loss: 1.9563 - val_accuracy: 0.2953 - val_loss: 1.7507 - learning_rate: 0.0010
# Epoch 2/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 44ms/step - accuracy: 0.2553 - loss: 1.8054 - val_accuracy: 0.2934 - val_loss: 1.7415 - learning_rate: 0.0010
# Epoch 3/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.2976 - loss: 1.7345 - val_accuracy: 0.2848 - val_loss: 1.7639 - learning_rate: 0.0010
# Epoch 4/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.3611 - loss: 1.6278 - val_accuracy: 0.3416 - val_loss: 1.6968 - learning_rate: 0.0010
# Epoch 5/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4104 - loss: 1.5227 - val_accuracy: 0.4659 - val_loss: 1.3843 - learning_rate: 0.0010
# Epoch 6/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.4513 - loss: 1.4300 - val_accuracy: 0.4923 - val_loss: 1.3025 - learning_rate: 0.0010
# Epoch 7/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.4853 - loss: 1.3457 - val_accuracy: 0.4996 - val_loss: 1.3061 - learning_rate: 0.0010
# Epoch 8/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5123 - loss: 1.2717 - val_accuracy: 0.5160 - val_loss: 1.2750 - learning_rate: 0.0010
# Epoch 9/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5272 - loss: 1.2400 - val_accuracy: 0.5545 - val_loss: 1.1748 - learning_rate: 0.0010
# Epoch 10/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5457 - loss: 1.1965 - val_accuracy: 0.5673 - val_loss: 1.1495 - learning_rate: 0.0010
# Epoch 11/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5577 - loss: 1.1649 - val_accuracy: 0.5539 - val_loss: 1.1765 - learning_rate: 0.0010
# Epoch 12/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.5588 - loss: 1.1582 - val_accuracy: 0.5812 - val_loss: 1.0915 - learning_rate: 0.0010
# Epoch 13/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 53ms/step - accuracy: 0.5766 - loss: 1.1262 - val_accuracy: 0.5949 - val_loss: 1.0728 - learning_rate: 0.0010
# Epoch 14/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.5859 - loss: 1.1022 - val_accuracy: 0.5977 - val_loss: 1.0702 - learning_rate: 0.0010
# Epoch 15/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.5952 - loss: 1.0778 - val_accuracy: 0.5765 - val_loss: 1.1181 - learning_rate: 0.0010
# Epoch 16/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.5927 - loss: 1.0797 - val_accuracy: 0.6149 - val_loss: 1.0460 - learning_rate: 0.0010
# Epoch 17/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6026 - loss: 1.0595 - val_accuracy: 0.5776 - val_loss: 1.1231 - learning_rate: 0.0010
# Epoch 18/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.6039 - loss: 1.0528 - val_accuracy: 0.6077 - val_loss: 1.0628 - learning_rate: 0.0010
# Epoch 19/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.6135 - loss: 1.0325 - val_accuracy: 0.6013 - val_loss: 1.0588 - learning_rate: 0.0010
# Epoch 20/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6122 - loss: 1.0309
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.6122 - loss: 1.0309 - val_accuracy: 0.5815 - val_loss: 1.1039 - learning_rate: 0.0010
# 總訓練時間: 7.17 分鐘

# %%
# 使用 PrivateTest 資料進行最終測試（泛化能力評估）
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"PrivateTest 測試準確率: {test_acc:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6191 - loss: 1.0240
# PrivateTest 測試準確率: 0.6155

# %%
# === 資料增強前後圖像展示 ===

# 任意挑選一張訓練集圖片（這裡選第500張）
sample_index = 500
sample_img = X_train[sample_index]
sample_img_expanded = np.expand_dims(sample_img, axis=0)  # 加上 batch 維度

# 用 datagen 增強
aug_iter = datagen.flow(sample_img_expanded, batch_size=1)

# 畫出原圖 + 增強後的前4張圖
plt.figure(figsize=(10, 2))

# 原圖
plt.subplot(1, 5, 1)
plt.imshow(sample_img.squeeze(), cmap='gray')
plt.title("Original")
plt.axis('off')

# 增強圖
for i in range(4):
    aug_img = next(aug_iter)[0]
    plt.subplot(1, 5, i + 2)
    plt.imshow(aug_img.squeeze(), cmap='gray')
    plt.title(f"Augmented {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# 使用測試集做預測
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
# 顯示每一類的 precision、recall、f1-score
print("Classification Report (F1-score):")
print(classification_report(y_true, y_pred, target_names=label_map))

# 計算混淆矩陣
conf_matrix = confusion_matrix(y_true, y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step
# Classification Report (F1-score):
#               precision    recall  f1-score   support
#
#        Anger       0.57      0.55      0.56       491
#      Disgust       0.55      0.20      0.29        55
#         Fear       0.40      0.43      0.42       528
#        Happy       0.83      0.87      0.85       879
#          Sad       0.47      0.50      0.49       594
#     Surprise       0.68      0.73      0.70       416
#      Neutral       0.64      0.53      0.58       626
#
#     accuracy                           0.62      3589
#    macro avg       0.59      0.54      0.56      3589
# weighted avg       0.62      0.62      0.61      3589

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_map, yticklabels=label_map)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()

# %%
# === 展示 Loss 與 Accuracy 隨 Epoch 變化 ===

# 繪製 Loss 曲線圖
plt.figure(figsize=(12, 4))

# Loss 圖
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Accuracy 圖
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
